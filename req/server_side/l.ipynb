# %%
import pandas as pd

# %%
df = pd.read_excel("data.xlsx")

# %%
df.head()
# Out:
#    CC  CC Delivery time (Business days)  \
# 0  KR                                25
# 1  KR                                25
# 2  KR                                25
# 3  KR                                25
# 4  KR                                25
#
#    CC Reordeing frequency (business days)  Additional Buffer to be ordered  \
# 0                                      22                             0.25
# 1                                      22                             0.25
# 2                                      22                             0.25
# 3                                      22                             0.25
# 4                                      22                             0.25
#
#      Location Location City  Catalogue Type      Model Desgination  \
# 0  9AAE100499    Cheonan-si  (Cases & Bags)            (Backpacks)
# 1  9AAE101713         Busan  (Cases & Bags)            (Backpacks)
# ...

# %%
df.columns
# Out:
# Index(['CC', 'CC Delivery time (Business days)',
#        'CC Reordeing frequency (business days)',
#        'Additional Buffer to be ordered', 'Location', 'Location City',
#        'Catalogue Type', 'Model Desgination', 'Part_Number',
#        ' Part Description', 'Part Type (Stock Vs Non Stock)',
#        'Order Calculation \nBased On', 'M1', 'M2', 'M3', 'M4', 'M5', 'M6',
#        'avg_demand_per_month', 'avg_demand/day', 'Pending_Task',
#        'Lease In Months', 'Instock', 'quantity_on_order', 'Proposal ID', 'Key',
#        'quantity_to_order(calc)', 'Trend_fit', 'Price\n(KRW)_x',
#        'total_price_calc', 'Price\n(KRW)_y'],
#       dtype='object')

# %%
selected_columns_for_dashboard = df[[
    'Part_Number', 'Location', 'Location City', 'Model Desgination', 'Trend_fit', 'Price\n(KRW)_x', 'total_price_calc']]

# %%
selected_columns_for_srp = df[[
    'Part_Number', 'Location', 'Location City', 'Model Desgination', 'Trend_fit', 'Price\n(KRW)_x', 'total_price_calc']]

# %%
selected_columns_for_Catalogue = df[[
    'Part_Number', 'Location', 'Location City', 'Model Desgination', 'Price\n(KRW)_x']]

# %%
selected_columns_for_Catalogue.shape
# Out:
# (217, 5)

# %%
asd=selected_columns_for_Catalogue.groupby(['Part_Number', 'Location'])

# %%
asd.mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16368\2307251484.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   asd.mean()
#                         Price\n(KRW)_x
# Part_Number Location
# 0A36271     9AAE100499        38843.28
#             9AAE101713        38843.28
#             9AAE105104        38843.28
# 0A36537     9AAE100499        20808.90
# 0A61769     9AAE100499        45779.58
# ...                                ...
# 63CFMARXKR  9AAE105104       192829.14
# 78Y2361     9AAE100499        49941.36
#             9AAE101713        49941.36
#             9AAE105104        49941.36
# ZDT-00004   9AAE100499      1847039.58
#
# [206 rows x 1 columns]

# %%
selected_columns_for_Catalogue.drop_duplicates(
    subset=['Part_Number', 'Location'])
# Out:
#     Part_Number    Location Location City      Model Desgination  \
# 0    4X41A30364  9AAE100499    Cheonan-si            (Backpacks)
# 1    4X41A30364  9AAE101713         Busan            (Backpacks)
# 2    4X41A30364  9AAE105104         Seoul            (Backpacks)
# 3    4X41A30365  9AAE100499    Cheonan-si  (Briefcases\Toploads)
# 4    4X41A30365  9AAE101713         Busan  (Briefcases\Toploads)
# ..          ...         ...           ...                    ...
# 212  21LLS12R01  9AAE100499    Cheonan-si               (Tablet)
# 213  21LLS12R01  9AAE101713         Busan               (Tablet)
# 214  4XD1M45626  9AAE105104         Seoul             (Headsets)
# 215  4XD1M45626  9AAE100499    Cheonan-si             (Headsets)
# 216  4XD1M45626  9AAE101713         Busan             (Headsets)
#
#      Price\n(KRW)_x
# 0          49941.36
# 1          49941.36
# 2          49941.36
# 3          38843.28
# 4          38843.28
# ..              ...
# 212      1935227.70
# ...
